# %% [markdown]
# <a href="https://colab.research.google.com/github/nandhakishornair/transportation-data-analysis-python/blob/main/day30_model_comparison.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Day 30 – Congestion Model Comparison

# %% [markdown]
# Logistic Regression Results

# %% [markdown]
# ```
#               precision    recall  f1-score   support
#
#            0       0.92      1.00      0.96        22
#            1       0.00      0.00      0.00         2
#
#     accuracy                           0.92        24
#    macro avg       0.46      0.50      0.48        24
# weighted avg       0.84      0.92      0.88        24
#
# confusion matrix:
# [[22  0]
#  [ 2  0]]
#
# ```

# %% [markdown]
#  Random Forest Results

# %% [markdown]
# ```
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        24
#
#     accuracy                           1.00        24
#    macro avg       1.00      1.00      1.00        24
# weighted avg       1.00      1.00      1.00        24
#
# confusion matrix
# [[24]]
#
# ```
