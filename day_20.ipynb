# %% [markdown]
# residuals??
# calculataion
# ploting and interpretation in regression model!

# %% [markdown]
# resudue states how wrong the model is

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#data sample
x = np.array([1, 2, 3, 4, 5])
y = np.array([3, 5, 7, 9, 10])
#fit regression line
slope, intercept = np.polyfit(x, y, 1)
#predict values
y_pred = slope * x + intercept
#calculate residuals
residuals = y - y_pred
print("residual ",residuals)
# Out:
# residual  [-0.2  0.   0.2  0.4 -0.4]

# %%
plt.scatter(x, residuals)
plt.axhline(0)
plt.title("Residual Plot")
plt.xlabel("x")
plt.ylabel("Residual")
plt.show()
